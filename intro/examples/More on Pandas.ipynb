# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import numpy as np

# %%
data_1 = pd.read_csv('data/data_00.csv')
data_1.head()
# Out:
#   account_id  last_month_balance          city  gender                 job  \
# 0   bh1b7a7e              310000    Kotamobagu  female  Cruise line worker
# 1   cd3a4c5c                6000      Pariaman    male  Software Architect
# 2   cg7a1a1i              104000      Semarang  female             Au pair
# 3   fc2i7b7d               23000      Bengkulu  female        Truck driver
# 4   ff1g8d4h               11000  Gunungsitoli  female      Camp counselor
#
#    month  active_income  passive_income
# 0      1        4560000               0
# 1      1        4940000               0
# 2      1        6840000               0
# 3      1        7220000               0
# 4      1        3040000               0

# %%
data_1.describe()
# Out:
#        last_month_balance    month  active_income  passive_income
# count        5.000000e+04  50000.0   5.000000e+04         50000.0
# mean         1.964229e+07      1.0   5.180160e+06             0.0
# std          7.638439e+08      0.0   3.142640e+06             0.0
# min          0.000000e+00      1.0   1.520000e+06             0.0
# 25%          7.000000e+03      1.0   2.660000e+06             0.0
# 50%          2.100000e+04      1.0   4.940000e+06             0.0
# 75%          9.900000e+04      1.0   7.220000e+06             0.0
# max          1.239535e+11      1.0   1.406000e+07             0.0

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
# account_id            50000 non-null object
# last_month_balance    50000 non-null int64
# city                  50000 non-null object
# gender                50000 non-null object
# job                   50000 non-null object
# month                 50000 non-null int64
# active_income         50000 non-null int64
# passive_income        50000 non-null int64
# dtypes: int64(4), object(4)
# memory usage: 3.1+ MB

# %%
data_1.job.unique()
# Out:
# array(['Cruise line worker', 'Software Architect', 'Au pair',
#        'Truck driver', 'Camp counselor', 'Barista', 'Physical therapists',
#        'Teacher/tutor', 'Data Scientist', 'Mobile Developer',
#        'Stock clerk', 'Lead engineer', 'Flight attendant', 'Translator',
#        'Nurse practitioners', 'Physician assistants', 'Waiter/waitress',
#        'Software QA engineer', 'Travel agent', 'Commercial divers',
#        'Senior java developer', 'Retail sales', 'Cashier',
#        'Call center representative', 'Medical transcriptionist',
#        'Lead developer', 'Franchise owner', 'Statisticians',
#        'Traveling nurse', 'UX Designer', 'Recruiter',
#        'English as a second language (ESL) teacher',
#        'Chief technology officer', 'Web developer/designer',
#        'Occupational therapy assistants/aids', 'Analytics Manager',
#        'Writer/editor', 'Sales representative', 'Tech support specialist',
# ...

# %%
data_1.job.value_counts()
# Out:
# Data Scientist                                941
# Home health aids                              937
# Research assistant                            924
# Tech support specialist                       913
# Lead engineer                                 913
# QA Manager                                    912
# Travel agent                                  907
# Recruiter                                     905
# Chief technology officer                      903
# Traveling nurse                               902
# Barista                                       901
# Software Architect                            901
# Warehouse worker                              901
# Full stack developer                          899
# Statisticians                                 899
# Teacher/tutor                                 899
# Nurse practitioners                           899
# Analytics Manager                             892
# Sales representative                          889
# ...

# %%
len(data_1)
# Out:
# 50000

# %%
# concat table
data_2 = pd.read_csv('data/data_01.csv')
data_2.head()
# Out:
#   account_id  last_month_balance          city  gender                 job  \
# 0   bh1b7a7e              310000    Kotamobagu  female  Cruise line worker
# 1   cd3a4c5c                6000      Pariaman    male  Software Architect
# 2   cg7a1a1i              104000      Semarang  female             Au pair
# 3   fc2i7b7d               23000      Bengkulu  female        Truck driver
# 4   ff1g8d4h               11000  Gunungsitoli  female      Camp counselor
#
#    month  active_income  passive_income
# 0      2        4560000               0
# 1      2        4940000               0
# 2      2        6840000               0
# 3      2        7220000               0
# 4      2        3040000               0

# %%
data_concat = pd.concat([data_1, data_2])
data_concat
# Out:
#           account_id  last_month_balance          city  gender  \
# 0           bh1b7a7e              310000    Kotamobagu  female
# 1           cd3a4c5c                6000      Pariaman    male
# 2           cg7a1a1i              104000      Semarang  female
# 3           fc2i7b7d               23000      Bengkulu  female
# 4           ff1g8d4h               11000  Gunungsitoli  female
# ...              ...                 ...           ...     ...
# 49995  ba9j3i7g2e2d6               11000        Kupang  female
# 49996  ba9j4c2i5a9i0               11000   Lhokseumawe    male
# 49997  ba9j4h3h4c9h7                5000    Payakumbuh  female
# 49998  ba9j4h8c4f1a0               14000    Payakumbuh  female
# 49999  ba9j4i3i1h4b6                1000    Singkawang  female
#
#                       job  month  active_income  passive_income
# 0      Cruise line worker      1        4560000               0
# 1      Software Architect      1        4940000               0
# ...

# %%
data_concat[data_concat.account_id=='bh1b7a7e']
# Out:
#   account_id  last_month_balance        city  gender                 job  \
# 0   bh1b7a7e              310000  Kotamobagu  female  Cruise line worker
# 0   bh1b7a7e              310000  Kotamobagu  female  Cruise line worker
#
#    month  active_income  passive_income
# 0      1        4560000               0
# 0      2        4560000               0
